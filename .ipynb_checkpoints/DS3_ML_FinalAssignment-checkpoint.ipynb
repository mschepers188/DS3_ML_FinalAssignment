# %%
# Importing necessary libraries
# Plotting and general purpose
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# PCA for data subselection
from pca import pca
# Testing different models
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# # DS3 Supervised learning - Final Assignment
#
# ## Background
#
# The selected dataset is a [divorce predictor data set](http://archive.ics.uci.edu/ml/datasets/Divorce+Predictors+data+set#) that was used to construct a neural network used to predict whether a divorce would happen ([See article](https://dergipark.org.tr/en/pub/nevsosbilen/issue/46568/549416)). A questionnaire containing 54 questions was filled in by 170 participants, wheras 84 (49%) were divorced and 86 (51%) were married couples. Using this data a model will be generated that can predict whether someone will or not get a divorce.

# %% [markdown]
# ## Data exploration

# %%
# data from http://archive.ics.uci.edu/ml/datasets/Divorce+Predictors+data+set#
# read in the data
df = pd.read_csv('data/divorce.csv', sep=';')
print(df.shape)  # print data shape
df.head()  # print first five rows
# Out:
# (170, 55)
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      2
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      3
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      2
#
#    Atr47  Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0      1      3      3      3      2      3      2      1      1
# 1      2      3      4      4      4      4      2      2      1
# 2      2      3      1      1      1      2      2      2      1
# 3      2      3      3      3      3      2      2      2      1
# 4      1      2      3      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %% [markdown]
# There are 170 samples, where each sample has 54 features. This is a rather large number of features and preferably should become smaller if possible.

# %%
# describe the dataset
df.describe()
# Out:
#              Atr1        Atr2        Atr3        Atr4        Atr5        Atr6  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     1.776471    1.652941    1.764706    1.482353    1.541176    0.747059
# std      1.627257    1.468654    1.415444    1.504327    1.632169    0.904046
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      2.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 75%      3.000000    3.000000    3.000000    3.000000    3.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#              Atr7        Atr8        Atr9       Atr10  ...       Atr46  \
# count  170.000000  170.000000  170.000000  170.000000  ...  170.000000
# mean     0.494118    1.452941    1.458824    1.576471  ...    2.552941
# std      0.898698    1.546371    1.557976    1.421529  ...    1.371786
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000  ...    2.000000
# 50%      0.000000    1.000000    1.000000    2.000000  ...    3.000000
# 75%      1.000000    3.000000    3.000000    3.000000  ...    4.000000
# max      4.000000    4.000000    4.000000    4.000000  ...    4.000000
#
#             Atr47       Atr48       Atr49       Atr50       Atr51       Atr52  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     2.270588    2.741176    2.382353    2.429412    2.476471    2.517647
# std      1.586841    1.137348    1.511587    1.405090    1.260238    1.476537
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    2.000000    1.000000    1.000000    2.000000    1.000000
# 50%      2.000000    3.000000    3.000000    2.000000    3.000000    3.000000
# 75%      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#             Atr53       Atr54       Class
# count  170.000000  170.000000  170.000000
# mean     2.241176    2.011765    0.494118
# std      1.505634    1.667611    0.501442
# min      0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000
# 50%      2.000000    2.000000    0.000000
# 75%      4.000000    4.000000    1.000000
# max      4.000000    4.000000    1.000000
#
# [8 rows x 55 columns]

# %% [markdown]
# As previously stated, there are 54 questions and according to the above table the answers seem to be answered on a scale from 0-4. The final column (class) holds only 1's and 0's and tell whether a divorce happened or not. Thus, there is no need to normalize this data as it all in in the same range and the final column is only a label.

# %%
# There do not seem to be any missing values in the data
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# To view the distribution of the answers, a histograms were generated in the next step.

# %%
# To view the distribution of the data, for each question a histogram is generated
fig, axis = plt.subplots(11,5,figsize=(18, 18))
df.hist(ax=axis)
plt.show()

# %% [markdown]
# According to the above plots, nothing in particular stands out. The data seems to be distributed randomly. Additionally, considering the number of features, it is very difficult to say anything about this data.
#
# ## Cleaning the data and dimensionality reduction
#
# According to the paper which used this data, divorce was explained in large part by 6 features. Thus, to reduce dimensionality a PCA will be performed to determine the most important features. This subselection will be then used to train the model.

# %%
# We do not need the labels (Divorce, no divorce)
df_unlabeled = df.drop('Class', axis=1)
# Save divorce labels in a different variable
divorce_label = df['Class']

# %%
# Creating model which considers 5 principal components,
# no normalization necessary due to data being in the same scale.
model = pca(n_components=5, normalize=False)
results = model.fit_transform(df_unlabeled)
# Out:
# [pca] >Processing dataframe..
# [pca] >The PCA reduction is performed on the [54] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[5]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]

# %%
# Plot the model to see how much is explained by how many principal components
model.plot(figsize=(10,8))
plt.show()

# %% [markdown]
# The above plot suggests a single component already seems to explain about 80% of all data. With 5 components, circa 86% of the variance in the dataset is explained. For further insight a biplot will be generated to observe the most important features. The paper claims that the divorces are mainly explained by 6 features, thus we'll use this value.

# %%
# show the top 6 features in a biplot
model.biplot(n_feat=6,  legend=True, figsize=(16,12), y=divorce_label, label=True)
plt.show()
# Out:
# [pca] >Plot PC1 vs PC2 with loadings.

# %% [markdown]
# According to the biplot, the main features responsible for a couple having a divorce or not seem to be: 'Atr1', 'Atr35', 'Atr45', 'Atr46', 'Atr49', 'Atr52'.
#
# These refer to the following questions:
# * Atr1: If one of us apologizes when our discussion deteriorates, the discussion ends.
# * Atr35: I can insult my spouse during our discussions.
# * Atr45: I'd rather stay silent than discuss with my spouse.
# * Atr46: Even if I'm right in the discussion, I stay silent to hurt my spouse.
# * Atr49: I have nothing to do with what I've been accused of.
# * Atr52: I wouldn't hesitate to tell my spouse about her/his inadequacy.
#
# Both groups seem to be split very well along PC1 with a few outliers closer to the non-divorced group. There also seems to be a little more variation within the divorced group than the non-divorced group.

# %%
# In the selection we include the 6 features and the labels
df_select = df[['Atr1', 'Atr35', 'Atr45', 'Atr46', 'Atr49', 'Atr52', 'Class']]
df_select.head()
# Out:
#    Atr1  Atr35  Atr45  Atr46  Atr49  Atr52  Class
# 0     2      0      3      2      3      3      1
# 1     4      0      2      2      4      4      1
# 2     2      1      2      3      1      2      1
# 3     3      1      3      2      3      2      1
# 4     2      0      2      2      3      2      1

# %%
# To view the distribution of this selection, a pairplot is generated
sns.pairplot(data=df_select, hue='Class', palette='RdBu')

# %% [markdown]
# For most of the features, there seems to be a clear distinction between both groups with some overlay.

# %% [markdown]
# ## Creating a simple model
#
# For initial classification, a logistic regression model will be constructed to give better insight to the data.

# %%
cols = ['Atr1', 'Atr35', 'Atr45', 'Atr46', 'Atr49', 'Atr52']  # column selection
y = np.array(df['Class'])  # Store outcome in an array
X = np.array(df[cols])  # Store selected columns in an array
print(X.shape)  # print the shape
# Out:
# (170, 6)

# %%
# Split the data in train data and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Train the model using Logistic regression
logreg = LogisticRegression()
history = logreg.fit(X_train, y_train)

# %%
# Evaluate the trained model using the test data.
y_pred = logreg.predict(X_test)
confusion_m = confusion_matrix(y_test, y_pred)
# print the confusion matrix to view how correct the model works.
print ('=== [confusion matrix] ==='.center(54))
print(confusion_m)
print ('')
print ('=== [classification report] ==='.center(54))
print(classification_report(y_test, y_pred))
# Out:
#               === [confusion matrix] ===
# [[19  0]
#  [ 1 23]]
#
#            === [classification report] ===
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %% [markdown]
# The model actually looks quite good with values above 0.9 for precision, recall and f1-score. The confusion matrix also shows very few missclassifications.

# %%
# Print the coefficient for the model
print('Coefficients', logreg.coef_)
# print the mean squared error to see how correct the model is.
print('MSE: ', mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Coefficients [[ 1.11647493  1.19568983  0.24342276 -0.16412112  0.52984902  0.50574172]]
# MSE:  0.15249857033260467

# %% [markdown]
# ## Comparing multiple classifiers

# %% [markdown]
# The logistic regression model seemed to work properly, however it might be possible a different algorithm is a even better fit. For this reason, different machine learning algorithms will be used to determine the best fit for this dataset. The chosen algorithms are the ones that follow (Code taken from [towardsdatascience](https://towardsdatascience.com/quickly-test-multiple-models-a98477476f0)):
# * Logistic Regression: basic linear classifier
# * Random Forest: ensemble bagging classifier
# * K-Nearest Neighbors: instance based classifier
# * Support Vector Machines: maximum margin classifier
# * Gaussian Naive Bayes: probabilistic classifier
# * XGBoost: ensemble boosting classifier

# %%
def run_exps(X_train, y_train, X_test, y_test):
    '''
    Tests several common models to verify which one functions best for given data
    :param X_train: training split
    :param y_train: training target vector
    :param X_test: test split
    :param y_test: test target vector
    :return: DataFrame of predictions
    '''
    
    # create lists which are used in loop
    dfs = []
    models = [
        ('LogReg', LogisticRegression()),
        ('RF', RandomForestClassifier()),
        ('KNN', KNeighborsClassifier()),
        ('SVM', SVC()),
        ('GNB', GaussianNB()),
        ('XGB', XGBClassifier())]
    
    results = []
    names = []
    scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
    target_names = ['0', '1']
    
    # loop through models, assessing several parameters
    for name, model in models:
        kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=90210)
        cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring)
        clf = model.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        # print parameters
        print(name)
        print(classification_report(y_test, y_pred, target_names=target_names))
        results.append(cv_results)
        names.append(name)
        
        # create df and append to dfs
        this_df = pd.DataFrame(cv_results)
        this_df['model'] = name
        dfs.append(this_df)

    # concatenate dfs and return final dataframe
    final = pd.concat(dfs, ignore_index=True)
    return final

# %%
# store output for bootstrapping
final = run_exps(X_train, y_train, X_test, y_test)
# Out:
# LogReg
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43
#
# RF
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        19
#            1       0.96      0.96      0.96        24
#
#     accuracy                           0.95        43
#    macro avg       0.95      0.95      0.95        43
# weighted avg       0.95      0.95      0.95        43
#
# KNN
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       0.96      1.00      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.98      0.97      0.98        43
# weighted avg       0.98      0.98      0.98        43
#
# SVM
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43
#
# GNB
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        19
#            1       1.00      0.92      0.96        24
#
#     accuracy                           0.95        43
#    macro avg       0.95      0.96      0.95        43
# weighted avg       0.96      0.95      0.95        43
#
# XGB
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       0.96      1.00      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.98      0.97      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %% [markdown]
# Due to the randomness when testing the models, values change every iteration due to the random state not being selected but there is some consistency as to how well a model fits the data. Overall, most models seem to perform very well with values ranging from 0.9 to 1.0.
#
# To better observe the models, bootstrapping will be performed. This method works as a substitution for repeating measurements. The available data is randomly selected whilst accepting duplicates to create a new dataset on which the model is then tested.

# %%
# perform bootstrapping with the different classifiers to verify which one is the best
bootstraps = []
# loop through models
for model in list(set(final.model.values)):
    model_df = final.loc[final.model == model]
    # only a subsection of data is selected, in this case 30.
    bootstrap = model_df.sample(n=30, replace=True)
    bootstraps.append(bootstrap)

# create dataframe containing the information
bootstrap_df = pd.concat(bootstraps, ignore_index=True)
results_long = pd.melt(bootstrap_df,id_vars=['model'],var_name='metrics', value_name='values')
time_metrics = ['fit_time','score_time'] # fit time metrics

# Performance metrics
# get df without fit data
results_long_nofit = results_long.loc[~results_long['metrics'].isin(time_metrics)]
results_long_nofit = results_long_nofit.sort_values(by='values')

# Time metrics
# df with fit data
results_long_fit = results_long.loc[results_long['metrics'].isin(time_metrics)]
results_long_fit = results_long_fit.sort_values(by='values')

# %%
# plot comparison of models by different classification metrics
plt.figure(figsize=(20, 12))
sns.set(font_scale=2.5)
g = sns.boxplot(x="model", y="values", hue="metrics", data=results_long_nofit, palette="Set3")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Comparison of Model by Classification Metric')
plt.savefig('./benchmark_models_performance.png',dpi=300)

# %% [markdown]
# After running this script several times (due to the changing random state), LogReg seems to usually vary wildly, ranging from around 0.8 to 1.0.
#
# KNN and XGB in particular seem to usually stay above 0.9 and come very close to 1.0. SVM and RF usually behave similarly, however have a far larger standard deviation.

# %%
# plot comparison of models by fit and score time
plt.figure(figsize=(20, 12))
sns.set(font_scale=2.5)
g = sns.boxplot(x="model", y="values", hue="metrics", data=results_long_fit, palette="Set3")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Comparison of Model by Fit and Score Time')
plt.savefig('./benchmark_models_time.png',dpi=300)

# %% [markdown]
# After running this script several times, KNN, GNB, SVM and LogReg seem to always have a very low fit and time value (close to zero). XGB and RF however seem to take a lot longer.
#
# According to the comparison by classification metrics, KNN, XGB, SVM and RF seemed to be the better choices. However, considering the fit and score time, XGB and RF could better be dropped due to the relatively slow time. Leaving KNN and SVM to construct a model.

# %% [markdown]
# ## Hyperparameter tuning
#
# Before combining both models, hypterparameter tuning will be performed to get the best parameters for each model.
#
# ### [SVM](https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/)
#
# Considering there are 2 groups, divorced and non-divorced, Support Vector Machine (SVM) should be a proper model to split them. This algorithm creates a hyperplane in N-dimensions, where N is the number of features. Together with the optimal parameters, it should be able to properly split the two groups.

# %%
# train the model on train set
svm = SVC()
svm.fit(X_train, y_train)
 
# print prediction results
predictions_svm = svm.predict(X_test)
print(classification_report(y_test, predictions_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}
 
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.692 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.769 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.680 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.840 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.840 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.520 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.923 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters are {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'} with a score of 0.97

# %%
# create variables containing the best parameters
c_optimal = grid.best_params_['C']
gamma_optimal = grid.best_params_['gamma']
kernel_optimal = grid.best_params_['kernel']

# %%
# train the model on train set using optimal parameters
svm_optimal = SVC(C=c_optimal, gamma=gamma_optimal, kernel=kernel_optimal)
svm_optimal.fit(X_train, y_train)
 
# print prediction results
predictions_svm_optimal = svm_optimal.predict(X_test)
print(classification_report(y_test, predictions_svm_optimal))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        19
#            1       0.92      1.00      0.96        24
#
#     accuracy                           0.95        43
#    macro avg       0.96      0.95      0.95        43
# weighted avg       0.96      0.95      0.95        43

# %% [markdown]
# Once again, the model seems to perform very well, with the averages usually being 0.95 and above.

# %% [markdown]
# ### [KNN](https://medium.datadriveninvestor.com/k-nearest-neighbors-in-python-hyperparameters-tuning-716734bc557f)
#
# k-nearest neighbors (KNN) is a algorithm used to find datapoints that cluster together, this is also the case for the divorce data. As seen during the data exploration and the PCA, divorced and non-divorced persons seem to answer some of the questions quite differently. They then end up forming different clusters, and by finding the optimal parameters for this model, it should also be able to properly classify the data.

# %%
#Train KNN model.
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print prediction results
predictions_knn = knn.predict(X_test)
print(classification_report(y_test, predictions_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       0.96      1.00      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.98      0.97      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %%
# defining parameter range
leaf_size = list(range(1,50,1))
n_neighbors = list(range(1,30,1))
p=[1,2]

#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p) 

#Create new KNN object
knn_2 = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)
#Fit the model
best_model = clf.fit(X_train, y_train)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 29
# Best p: 2
# Best n_neighbors: 7

# %%
print("The best parameters are %s with a score of %0.2f"
      % (best_model.best_estimator_.get_params(), best_model.best_score_))
# Out:
# The best parameters are {'algorithm': 'auto', 'leaf_size': 29, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'} with a score of 0.97

# %%
# create variables containing the best parameters
best_neigh = best_model.best_estimator_.get_params()['n_neighbors']
best_leaf = best_model.best_estimator_.get_params()['leaf_size']

# %%
# train the model on train set using optimal parameters
knn_optimal = KNeighborsClassifier(n_neighbors=best_neigh, leaf_size=best_leaf)
knn_optimal.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(leaf_size=29, n_neighbors=7)

# %%
# print prediction results
predictions_knn_optimal = knn_optimal.predict(X_test)
print(classification_report(y_test, predictions_knn_optimal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %% [markdown]
# After optimizing number of neighbors and leaf size, there usually does not seem to be any value lower then 0.95. At certain iterations numbers very close to or equal to 1.0 were seen.

# %% [markdown]
# ## Voting classifier
#
# After optimizing both selected models, a new model will be created by combining them. For this, we make use of an ensemble classifier called [Voting Classifier](https://vitalflux.com/hard-vs-soft-voting-classifier-python-example/). Voting consists of determining a classification based on the different weights given by the included models. Voting is divided in "hard" and "soft" voting, whereas each model has a weight given to it. Hard voting bases its choices on the predictions of given by each model, whereas soft voting instead uses probability.

# %%
# group / ensemble of models
estimator = []
# knn_optimal, svm_optimal
estimator.append(('KNN', 
                  KNeighborsClassifier(
                      n_neighbors=best_neigh, 
                      leaf_size=best_leaf
                  )))
estimator.append(('SVM', SVC(C=c_optimal, 
                             gamma=gamma_optimal, 
                             kernel=kernel_optimal,
                             probability=True
                            )))

# %%
# Voting Classifier with hard voting
vot_hard = VotingClassifier(estimators = estimator, voting ='hard')
vot_hard.fit(X_train, y_train)
y_pred = vot_hard.predict(X_test)
# See how well the hard voting model performs 
predictions_vot_hard = vot_hard.predict(X_test)
print(classification_report(y_test, predictions_vot_hard))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      0.96      0.98        24
#
#     accuracy                           0.98        43
#    macro avg       0.97      0.98      0.98        43
# weighted avg       0.98      0.98      0.98        43

# %%
# Voting Classifier with soft voting
vot_soft = VotingClassifier(estimators = estimator, voting ='soft')
vot_soft.fit(X_train, y_train)
y_pred = vot_soft.predict(X_test)
# See how well the soft voting model performs 
predictions_vot_soft = vot_soft.predict(X_test)
print(classification_report(y_test, predictions_vot_soft))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        43
#    macro avg       1.00      1.00      1.00        43
# weighted avg       1.00      1.00      1.00        43

# %%
def plot_learning_curves(model, X_train, y_train, X_val, y_val):
    """
    input:
        model:pipeline object
        X_train, y_train: training data
        X_val, y_val: test data
    """
    train_errors, val_errors = [], []
    for m in range(30, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m]))
        val_errors.append(mean_squared_error(y_val_predict, y_val))

    plt.plot(np.sqrt(train_errors), "r-+", linewidth=1, label="training data")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=1, label="validation data")
    plt.legend(loc="upper right", fontsize=10)   
    plt.xlabel("Training set size", fontsize=10) 
    plt.ylabel("RMSE", fontsize=10)     
    # compare accuracy train versus test to access overfit 
    print(f'test  acc: {model.score(X_val, y_val)}')
    print(f'train acc: {model.score(X_train, y_train)}')

plot_learning_curves(vot_hard, X_train, y_train, X_test, y_test)
# Out:
# test  acc: 0.9767441860465116
# train acc: 0.9763779527559056

# %%
plot_learning_curves(vot_soft, X_train, y_train, X_test, y_test)
# Out:
# test  acc: 1.0
# train acc: 1.0

# %% [markdown]
# Both the hard voting as well as soft voting seems to perform very well, with values normally above 95%. The soft voting however, seems to usually perform slightly better then the hard voting. The opimal training dataset also seems to be around 30 at most iterations.
#
# ## Conclusion
#
# The best model through trial and error seems to be a Voting Classifier which uses SVM and KNN with each it's optimal parameters. Accuracy, recall and F1-score all are normally above 95%. By answering the 6 selected questions and using the model, it should be able to predict with 95-100% certainty whether a divorce will happen. This of course, should be taken with a grain of salt. "Love" is something very subjective and certain couples who may seem to be a very poor fit with each other, sometimes have a long lasting relationship.
#
# That said, this model still should be able to properly predict the majority of the cases using these six questions. Splitting the data, training the model and then it on the remaining data still provided very high precision, recall and accuracy. This does suggest these questions are related to very important behaviours that can often lead to a divorce.
#
# Finally, this model could thus be used to see whether a divorce might happen and correct any bad behaviours that might lead to that.
